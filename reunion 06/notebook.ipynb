# %%
# Celda 1: Importaciones y Carga de Datos
import pandas as pd
import os

# Configurar pandas para una mejor visualización en el notebook
pd.set_option('display.max_colwidth', 80)
pd.set_option('display.width', 150)
pd.set_option('display.max_rows', 100)

# --- 1. EJECUTAR EL SCRIPT DE ANÁLISIS PRINCIPAL ---
# Asegúrate de que la ruta al script sea la correcta desde la ubicación de tu notebook
script_path = '../scripts/ejecutar_analisis_clivajes_REU_06-08.py'

# Descomenta la siguiente línea para ejecutar el script desde el notebook si lo necesitas.
# Es mejor ejecutarlo desde la terminal si es un proceso largo.
# print("Ejecutando script de análisis... Esto puede tardar varios minutos.")
# %run {script_path}
# print("Script finalizado.")

# --- 2. CARGAR LOS RESULTADOS GENERADOS ---
results_dir = '../results'
try:
    df_terminos = pd.read_csv(os.path.join(results_dir, 'exp_analisis_terminos.csv'), sep=';')
    df_nodos = pd.read_csv(os.path.join(results_dir, 'exp_analisis_nodos.csv'), sep=';')
    df_metricas = pd.read_csv(os.path.join(results_dir, 'exp_metricas_polarizacion.csv'), sep=';')
    
    print("Archivos de resultados cargados exitosamente.")
    print(f"Términos encontrados: {len(df_terminos)} filas")
    print(f"Nodos centrales encontrados: {len(df_nodos)} filas")
    
except FileNotFoundError as e:
    print(f"Error: No se encontró el archivo de resultados. Asegúrate de haber ejecutado el script primero.")
    print(e)
# Out:
# Archivos de resultados cargados exitosamente.
# Términos encontrados: 1304 filas
# Nodos centrales encontrados: 75 filas

# %%
# Celda 2: Función para Mostrar Resultados de Forma Ordenada

def mostrar_analisis_completo(df_terminos, df_nodos, dataset, algoritmo, ngram_tipo):
    """
    Filtra y muestra una tabla comparativa con los top términos y nodos para una configuración específica.
    """
    
    print("="*80)
    print(f"Análisis para: DATASET={dataset} | ALGORITMO={algoritmo} | N-GRAMS={ngram_tipo}")
    print("="*80)
    
    # Filtrar datos para la configuración actual
    terminos_filtrados = df_terminos[
        (df_terminos['Dataset'] == dataset) & 
        (df_terminos['Algoritmo'] == algoritmo) & 
        (df_terminos['Tipo_Ngram'] == ngram_tipo)
    ]
    
    nodos_filtrados = df_nodos[
        (df_nodos['Dataset'] == dataset) & 
        (df_nodos['Algoritmo'] == algoritmo)
    ]
    
    if terminos_filtrados.empty or nodos_filtrados.empty:
        print("\nNo se encontraron datos para esta combinación.\n")
        return

    # Preparar DataFrames para la visualización
    # Clúster S1 (Apruebo)
    terminos_s1 = terminos_filtrados[terminos_filtrados['Cluster'] == 'S1_Apruebo'][['Termino', 'Score_TFIDF_Avg']].head(10).reset_index(drop=True)
    nodos_s1 = nodos_filtrados[nodos_filtrados['Cluster'] == 'S1'][['Nodo', 'Grado']].head(5).reset_index(drop=True)
    terminos_s1.columns = [f'Top 10 Términos (S1_{ngram_tipo})', 'Score']
    nodos_s1.columns = ['Top 5 Nodos (S1)', 'Grado']
    
    # Clúster S2 (Rechazo)
    terminos_s2 = terminos_filtrados[terminos_filtrados['Cluster'] == 'S2_Rechazo'][['Termino', 'Score_TFIDF_Avg']].head(10).reset_index(drop=True)
    nodos_s2 = nodos_filtrados[nodos_filtrados['Cluster'] == 'S2'][['Nodo', 'Grado']].head(5).reset_index(drop=True)
    terminos_s2.columns = [f'Top 10 Términos (S2_{ngram_tipo})', 'Score']
    nodos_s2.columns = ['Top 5 Nodos (S2)', 'Grado']
    
    # Unir los dataframes para una visualización lado a lado
    df_display_terminos = pd.concat([terminos_s1, terminos_s2], axis=1).fillna('')
    df_display_nodos = pd.concat([nodos_s1, nodos_s2], axis=1).fillna('')
    
    print("\n--- ANÁLISIS DE TÉRMINOS ---")
    print(df_display_terminos.to_string())
    
    print("\n\n--- ANÁLISIS DE NODOS CENTRALES ---")
    print(df_display_nodos.to_string())
    print("\n\n")


# Celda 3: Iterar y Mostrar Todos los Resultados

# Obtener listas únicas para iterar
datasets = df_terminos['Dataset'].unique()
algoritmos = df_terminos['Algoritmo'].unique()
ngram_tipos = df_terminos['Tipo_Ngram'].unique()

for dataset in datasets:
    for algoritmo in algoritmos:
        for ngram_tipo in ngram_tipos:
            mostrar_analisis_completo(df_terminos, df_nodos, dataset, algoritmo, ngram_tipo)
# Out:
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=Eigensign | N-GRAMS=Unigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Unigramas), Score, Top 10 Términos (S2_Unigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado   Top 5 Nodos (S2)  Grado
# 0     javier macaya    2.0      gabriel boric    298
# 1       felipe kast    1.0    giorgio jackson     95
# 2  jorge alessandri    1.0     camila vallejo     80
# 3                           michelle bachelet     54
# 4                                izkia siches     52
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=Eigensign | N-GRAMS=Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Bigramas), Score, Top 10 Términos (S2_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado   Top 5 Nodos (S2)  Grado
# 0     javier macaya    2.0      gabriel boric    298
# 1       felipe kast    1.0    giorgio jackson     95
# 2  jorge alessandri    1.0     camila vallejo     80
# 3                           michelle bachelet     54
# 4                                izkia siches     52
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=Eigensign | N-GRAMS=Uni_y_Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Uni_y_Bigramas), Score, Top 10 Términos (S2_Uni_y_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado   Top 5 Nodos (S2)  Grado
# 0     javier macaya    2.0      gabriel boric    298
# 1       felipe kast    1.0    giorgio jackson     95
# 2  jorge alessandri    1.0     camila vallejo     80
# 3                           michelle bachelet     54
# 4                                izkia siches     52
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=Random Eigensign | N-GRAMS=Unigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Unigramas), Score, Top 10 Términos (S2_Unigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#        Top 5 Nodos (S1)  Grado    Top 5 Nodos (S2)  Grado
# 0          eduardo frei      3       gabriel boric    443
# 1           felipe kast      3     giorgio jackson    100
# 2          daniel jadue      3      camila vallejo     87
# 3  democracia cristiana      2   michelle bachelet     62
# 4      ministro jackson      2  guillermo teillier     59
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=Random Eigensign | N-GRAMS=Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Bigramas), Score, Top 10 Términos (S2_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#        Top 5 Nodos (S1)  Grado    Top 5 Nodos (S2)  Grado
# 0          eduardo frei      3       gabriel boric    443
# 1           felipe kast      3     giorgio jackson    100
# 2          daniel jadue      3      camila vallejo     87
# 3  democracia cristiana      2   michelle bachelet     62
# 4      ministro jackson      2  guillermo teillier     59
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=Random Eigensign | N-GRAMS=Uni_y_Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Uni_y_Bigramas), Score, Top 10 Términos (S2_Uni_y_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#        Top 5 Nodos (S1)  Grado    Top 5 Nodos (S2)  Grado
# 0          eduardo frei      3       gabriel boric    443
# 1           felipe kast      3     giorgio jackson    100
# 2          daniel jadue      3      camila vallejo     87
# 3  democracia cristiana      2   michelle bachelet     62
# 4      ministro jackson      2  guillermo teillier     59
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=Local Search (b=0.01) | N-GRAMS=Unigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Unigramas), Score, Top 10 Términos (S2_Unigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#       Top 5 Nodos (S1)  Grado   Top 5 Nodos (S2)  Grado
# 0        javier macaya     18      gabriel boric    461
# 1        ricardo lagos     17    giorgio jackson     99
# 2         rojo edwards      9     camila vallejo     92
# 3         elisa loncon      7  michelle bachelet     67
# 4  juan antonio coloma      5       izkia siches     65
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=Local Search (b=0.01) | N-GRAMS=Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Bigramas), Score, Top 10 Términos (S2_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#       Top 5 Nodos (S1)  Grado   Top 5 Nodos (S2)  Grado
# 0        javier macaya     18      gabriel boric    461
# 1        ricardo lagos     17    giorgio jackson     99
# 2         rojo edwards      9     camila vallejo     92
# 3         elisa loncon      7  michelle bachelet     67
# 4  juan antonio coloma      5       izkia siches     65
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=Local Search (b=0.01) | N-GRAMS=Uni_y_Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Uni_y_Bigramas), Score, Top 10 Términos (S2_Uni_y_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#       Top 5 Nodos (S1)  Grado   Top 5 Nodos (S2)  Grado
# 0        javier macaya     18      gabriel boric    461
# 1        ricardo lagos     17    giorgio jackson     99
# 2         rojo edwards      9     camila vallejo     92
# 3         elisa loncon      7  michelle bachelet     67
# 4  juan antonio coloma      5       izkia siches     65
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=SCG (max_obj) | N-GRAMS=Unigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Unigramas), Score, Top 10 Términos (S2_Unigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado   Top 5 Nodos (S2)  Grado
# 0     javier macaya    2.0      gabriel boric    301
# 1       felipe kast    1.0    giorgio jackson     95
# 2  jorge alessandri    1.0     camila vallejo     80
# 3                           michelle bachelet     54
# 4                                izkia siches     52
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=SCG (max_obj) | N-GRAMS=Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Bigramas), Score, Top 10 Términos (S2_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado   Top 5 Nodos (S2)  Grado
# 0     javier macaya    2.0      gabriel boric    301
# 1       felipe kast    1.0    giorgio jackson     95
# 2  jorge alessandri    1.0     camila vallejo     80
# 3                           michelle bachelet     54
# 4                                izkia siches     52
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_PRE | ALGORITMO=SCG (max_obj) | N-GRAMS=Uni_y_Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Uni_y_Bigramas), Score, Top 10 Términos (S2_Uni_y_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado   Top 5 Nodos (S2)  Grado
# 0     javier macaya    2.0      gabriel boric    301
# 1       felipe kast    1.0    giorgio jackson     95
# 2  jorge alessandri    1.0     camila vallejo     80
# 3                           michelle bachelet     54
# 4                                izkia siches     52
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=Eigensign | N-GRAMS=Unigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Unigramas), Score, Top 10 Términos (S2_Unigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado    Top 5 Nodos (S2)  Grado
# 0     javier macaya      8       gabriel boric    344
# 1  jorge alessandri      5        mario marcel     72
# 2    fidel espinoza      2      camila vallejo     51
# 3       chile vamos      2     giorgio jackson     49
# 4   mario desbordes      1  guillermo teillier     44
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=Eigensign | N-GRAMS=Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Bigramas), Score, Top 10 Términos (S2_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado    Top 5 Nodos (S2)  Grado
# 0     javier macaya      8       gabriel boric    344
# 1  jorge alessandri      5        mario marcel     72
# 2    fidel espinoza      2      camila vallejo     51
# 3       chile vamos      2     giorgio jackson     49
# 4   mario desbordes      1  guillermo teillier     44
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=Eigensign | N-GRAMS=Uni_y_Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Uni_y_Bigramas), Score, Top 10 Términos (S2_Uni_y_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado    Top 5 Nodos (S2)  Grado
# 0     javier macaya      8       gabriel boric    344
# 1  jorge alessandri      5        mario marcel     72
# 2    fidel espinoza      2      camila vallejo     51
# 3       chile vamos      2     giorgio jackson     49
# 4   mario desbordes      1  guillermo teillier     44
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=Random Eigensign | N-GRAMS=Unigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Unigramas), Score, Top 10 Términos (S2_Unigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado Top 5 Nodos (S2)  Grado
# 0    jair bolsonaro     16    gabriel boric    427
# 1     javier macaya     10     mario marcel     81
# 2       chile vamos      7   camila vallejo     56
# 3  jorge alessandri      6  ana lya uriarte     53
# 4    diego schalper      6  giorgio jackson     51
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=Random Eigensign | N-GRAMS=Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Bigramas), Score, Top 10 Términos (S2_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado Top 5 Nodos (S2)  Grado
# 0    jair bolsonaro     16    gabriel boric    427
# 1     javier macaya     10     mario marcel     81
# 2       chile vamos      7   camila vallejo     56
# 3  jorge alessandri      6  ana lya uriarte     53
# 4    diego schalper      6  giorgio jackson     51
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=Random Eigensign | N-GRAMS=Uni_y_Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Uni_y_Bigramas), Score, Top 10 Términos (S2_Uni_y_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado Top 5 Nodos (S2)  Grado
# 0    jair bolsonaro     16    gabriel boric    427
# 1     javier macaya     10     mario marcel     81
# 2       chile vamos      7   camila vallejo     56
# 3  jorge alessandri      6  ana lya uriarte     53
# 4    diego schalper      6  giorgio jackson     51
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=Local Search (b=0.01) | N-GRAMS=Unigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Unigramas), Score, Top 10 Términos (S2_Unigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#   Top 5 Nodos (S1)  Grado Top 5 Nodos (S2)  Grado
# 0    karol cariola     32    gabriel boric    469
# 1    javier macaya     17     mario marcel     74
# 2     pamela jiles     16   camila vallejo     58
# 3      luz poblete     14  ana lya uriarte     56
# 4   diego schalper     10  giorgio jackson     51
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=Local Search (b=0.01) | N-GRAMS=Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Bigramas), Score, Top 10 Términos (S2_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#   Top 5 Nodos (S1)  Grado Top 5 Nodos (S2)  Grado
# 0    karol cariola     32    gabriel boric    469
# 1    javier macaya     17     mario marcel     74
# 2     pamela jiles     16   camila vallejo     58
# 3      luz poblete     14  ana lya uriarte     56
# 4   diego schalper     10  giorgio jackson     51
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=Local Search (b=0.01) | N-GRAMS=Uni_y_Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Uni_y_Bigramas), Score, Top 10 Términos (S2_Uni_y_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#   Top 5 Nodos (S1)  Grado Top 5 Nodos (S2)  Grado
# 0    karol cariola     32    gabriel boric    469
# 1    javier macaya     17     mario marcel     74
# 2     pamela jiles     16   camila vallejo     58
# 3      luz poblete     14  ana lya uriarte     56
# 4   diego schalper     10  giorgio jackson     51
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=SCG (max_obj) | N-GRAMS=Unigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Unigramas), Score, Top 10 Términos (S2_Unigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado    Top 5 Nodos (S2)  Grado
# 0     javier macaya    8.0       gabriel boric    339
# 1  jorge alessandri    5.0        mario marcel     71
# 2    fidel espinoza    2.0      camila vallejo     51
# 3       chile vamos    1.0     giorgio jackson     49
# 4                           guillermo teillier     44
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=SCG (max_obj) | N-GRAMS=Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Bigramas), Score, Top 10 Términos (S2_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado    Top 5 Nodos (S2)  Grado
# 0     javier macaya    8.0       gabriel boric    339
# 1  jorge alessandri    5.0        mario marcel     71
# 2    fidel espinoza    2.0      camila vallejo     51
# 3       chile vamos    1.0     giorgio jackson     49
# 4                           guillermo teillier     44
#
#
#
# ================================================================================
# Análisis para: DATASET=Plebiscito_POST | ALGORITMO=SCG (max_obj) | N-GRAMS=Uni_y_Bigramas
# ================================================================================
#
# --- ANÁLISIS DE TÉRMINOS ---
# Empty DataFrame
# Columns: [Top 10 Términos (S1_Uni_y_Bigramas), Score, Top 10 Términos (S2_Uni_y_Bigramas), Score]
# Index: []
#
#
# --- ANÁLISIS DE NODOS CENTRALES ---
#    Top 5 Nodos (S1)  Grado    Top 5 Nodos (S2)  Grado
# 0     javier macaya    8.0       gabriel boric    339
# 1  jorge alessandri    5.0        mario marcel     71
# 2    fidel espinoza    2.0      camila vallejo     51
# 3       chile vamos    1.0     giorgio jackson     49
# 4                           guillermo teillier     44

# %%
import pandas as pd

# Define las rutas a tus archivos de resultados
ruta_core = '../results/comparacion_metricas_core.csv'
ruta_paper = '../results/comparacion_metricas_paper.csv'
# Carga los CSV en DataFrames
df_core = pd.read_csv(ruta_core)
df_paper = pd.read_csv(ruta_paper)

df_paper.style \
    .format({
        "POL": "{:.3f}", "BA-POL": "{:.3f}", "BAL": "{:.2%}",
        "MAC": "{:.3f}", "MAO": "{:.3f}", "DENS": "{:.3f}",
        "ISO": "{:.3f}", "CC+": "{:.3f}", "CC-": "{:.3f}"
    }) \
    .background_gradient(
        cmap='RdYlGn',  # Rojo (bajo) a Verde (alto)
        subset=["POL", "BA-POL", "BAL", "ISO", "CC+", "CC-"]
    ) \
    .set_caption("🚀 Tabla 2: Métricas Detalladas")
# Out:
# <style type="text/css">
# #T_00c55_row0_col2 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_00c55_row0_col3, #T_00c55_row4_col2, #T_00c55_row4_col8, #T_00c55_row6_col7, #T_00c55_row9_col4, #T_00c55_row10_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_00c55_row0_col4 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_00c55_row0_col6, #T_00c55_row13_col2 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_00c55_row0_col7 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_00c55_row0_col8 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_00c55_row1_col2 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_00c55_row1_col3, #T_00c55_row3_col7 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_00c55_row1_col4 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_00c55_row1_col6 {
#   background-color: #ddf191;
#   color: #000000;
# }
# #T_00c55_row1_col7 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_00c55_row1_col8, #T_00c55_row11_col7 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_00c55_row2_col2 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_00c55_row2_col3 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_00c55_row2_col4 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_00c55_row2_col6 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_00c55_row2_col7, #T_00c55_row10_col2 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_00c55_row2_col8 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_00c55_row3_col2 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_00c55_row3_col3 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_00c55_row3_col4 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_00c55_row3_col6 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_00c55_row3_col8 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_00c55_row4_col3 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_00c55_row4_col4 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_00c55_row4_col6, #T_00c55_row8_col3 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_00c55_row4_col7 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_00c55_row5_col2 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_00c55_row5_col3 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_00c55_row5_col4 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_00c55_row5_col6 {
#   background-color: #d5ed88;
#   color: #000000;
# }
# #T_00c55_row5_col7 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_00c55_row5_col8 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_00c55_row6_col2 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_00c55_row6_col3 {
#   background-color: #ad0826;
#   color: #f1f1f1;
# }
# #T_00c55_row6_col4, #T_00c55_row11_col8, #T_00c55_row12_col3 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_00c55_row6_col6, #T_00c55_row7_col4, #T_00c55_row10_col7, #T_00c55_row10_col8, #T_00c55_row12_col2, #T_00c55_row13_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_00c55_row6_col8 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_00c55_row7_col2 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_00c55_row7_col3 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_00c55_row7_col6 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_00c55_row7_col7 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_00c55_row7_col8 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_00c55_row8_col2, #T_00c55_row13_col4 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_00c55_row8_col4, #T_00c55_row12_col4 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_00c55_row8_col6 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_00c55_row8_col7 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_00c55_row8_col8 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_00c55_row9_col2 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_00c55_row9_col3 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_00c55_row9_col6 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_00c55_row9_col7, #T_00c55_row11_col6 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_00c55_row9_col8 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_00c55_row10_col3 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_00c55_row10_col4 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_00c55_row11_col2 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_00c55_row11_col3 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_00c55_row11_col4 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_00c55_row12_col6 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_00c55_row12_col7 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_00c55_row12_col8 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_00c55_row13_col6 {
#   background-color: #c82227;
#   color: #f1f1f1;
# }
# #T_00c55_row13_col7 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_00c55_row13_col8 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# </style>
# <table id="T_00c55">
#   <caption>🚀 Tabla 2: Métricas Detalladas</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00c55_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_00c55_level0_col1" class="col_heading level0 col1" >Algoritmo</th>
#       <th id="T_00c55_level0_col2" class="col_heading level0 col2" >POL</th>
#       <th id="T_00c55_level0_col3" class="col_heading level0 col3" >BA-POL</th>
#       <th id="T_00c55_level0_col4" class="col_heading level0 col4" >BAL</th>
#       <th id="T_00c55_level0_col5" class="col_heading level0 col5" >SIZE</th>
#       <th id="T_00c55_level0_col6" class="col_heading level0 col6" >ISO</th>
#       <th id="T_00c55_level0_col7" class="col_heading level0 col7" >CC+</th>
#       <th id="T_00c55_level0_col8" class="col_heading level0 col8" >CC-</th>
#       <th id="T_00c55_level0_col9" class="col_heading level0 col9" >CC_intra_S1</th>
#       <th id="T_00c55_level0_col10" class="col_heading level0 col10" >CC_intra_S2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00c55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00c55_row0_col0" class="data row0 col0" >Plebiscito PRE</td>
#       <td id="T_00c55_row0_col1" class="data row0 col1" >Eigensign (Determinista)</td>
#       <td id="T_00c55_row0_col2" class="data row0 col2" >5.742</td>
#       <td id="T_00c55_row0_col3" class="data row0 col3" >4.698</td>
#       <td id="T_00c55_row0_col4" class="data row0 col4" >81.82%</td>
#       <td id="T_00c55_row0_col5" class="data row0 col5" >120</td>
#       <td id="T_00c55_row0_col6" class="data row0 col6" >0.176</td>
#       <td id="T_00c55_row0_col7" class="data row0 col7" >0.635</td>
#       <td id="T_00c55_row0_col8" class="data row0 col8" >0.880</td>
#       <td id="T_00c55_row0_col9" class="data row0 col9" >0.291981</td>
#       <td id="T_00c55_row0_col10" class="data row0 col10" >0.581879</td>
#     </tr>
#     <tr>
#       <th id="T_00c55_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00c55_row1_col0" class="data row1 col0" >Plebiscito PRE</td>
#       <td id="T_00c55_row1_col1" class="data row1 col1" >Random Eigensign (Probabilístico)</td>
#       <td id="T_00c55_row1_col2" class="data row1 col2" >2.373</td>
#       <td id="T_00c55_row1_col3" class="data row1 col3" >1.727</td>
#       <td id="T_00c55_row1_col4" class="data row1 col4" >72.77%</td>
#       <td id="T_00c55_row1_col5" class="data row1 col5" >660</td>
#       <td id="T_00c55_row1_col6" class="data row1 col6" >0.329</td>
#       <td id="T_00c55_row1_col7" class="data row1 col7" >0.603</td>
#       <td id="T_00c55_row1_col8" class="data row1 col8" >0.800</td>
#       <td id="T_00c55_row1_col9" class="data row1 col9" >0.112295</td>
#       <td id="T_00c55_row1_col10" class="data row1 col10" >0.357895</td>
#     </tr>
#     <tr>
#       <th id="T_00c55_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00c55_row2_col0" class="data row2 col0" >Plebiscito PRE</td>
#       <td id="T_00c55_row2_col1" class="data row2 col1" >Local Search (beta=0.01)</td>

# %%
# Celda de Análisis Detallado para el Algoritmo Seleccionado

import pandas as pd

# --- CONFIGURACIÓN ---
# Define el algoritmo que quieres analizar en detalle.
ALGORITMO_SELECCIONADO = 'Local Search (b=0.01)'
# Define los nombres de tus clústeres para facilitar el filtrado.
CLUSTER_S1 = 'S1_Apruebo'
CLUSTER_S2 = 'S2_Rechazo'
# Define cuántos términos de ejemplo quieres mostrar en las listas.
N_TERMINOS_A_MOSTRAR = 15

# --- INICIO DEL ANÁLISIS ---
print("=" * 90)
print(f"🔎 ANÁLISIS DETALLADO DE LA EVOLUCIÓN DEL DISCURSO PARA: '{ALGORITMO_SELECCIONADO}'")
print("=" * 90)

# Celda de Análisis para Presentación (Comparando Clústeres por Período)

import pandas as pd

# --- CONFIGURACIÓN ---
# Define el algoritmo que quieres analizar en detalle.
ALGORITMO_SELECCIONADO = 'Local Search (b=0.01)'
# Define los nombres de tus clústeres para facilitar el filtrado.
CLUSTER_S1 = 'S1'
CLUSTER_S2 = 'S2'
# Define cuántos términos quieres mostrar en las tablas.
N_TOP_TERMINOS = 15
# Define cuántos nodos quieres mostrar en las tablas.
N_TOP_NODOS = 5



# 1. ANÁLISIS DE TÉRMINOS POR TIPO DE N-GRAM
# Itera sobre cada tipo de n-grama para analizarlo por separado.
for ngram_tipo in df_terminos['Tipo_Ngram'].unique():
    print(f"\n\n{'='*30} Análisis para N-Grams: {ngram_tipo} {'='*30}")
    
    # Filtra el DataFrame de términos para el algoritmo y n-gram actual.
    terminos_filtrados = df_terminos[
        (df_terminos['Algoritmo'] == ALGORITMO_SELECCIONADO) & 
        (df_terminos['Tipo_Ngram'] == ngram_tipo)
    ]
    
    # --- TABLA 1: ANÁLISIS PRE-PLEBISCITO ---
    print("\n--- 🗓️  Discurso ANTES del Plebiscito (S1 vs S2) ---\n")
    
    terminos_pre = terminos_filtrados[terminos_filtrados['Dataset'] == 'Plebiscito_PRE']
    
    # Prepara las columnas para la tabla comparativa PRE
    terminos_pre_s1 = terminos_pre[terminos_pre['Cluster'] == CLUSTER_S1][['Termino', 'Score_TFIDF_Avg']].head(N_TOP_TERMINOS).reset_index(drop=True)
    terminos_pre_s2 = terminos_pre[terminos_pre['Cluster'] == CLUSTER_S2][['Termino', 'Score_TFIDF_Avg']].head(N_TOP_TERMINOS).reset_index(drop=True)
    
    df_display_pre = pd.concat([
        terminos_pre_s1.rename(columns={'Termino': f'Top Términos ({CLUSTER_S1})', 'Score_TFIDF_Avg': 'Score'}),
        terminos_pre_s2.rename(columns={'Termino': f'Top Términos ({CLUSTER_S2})', 'Score_TFIDF_Avg': 'Score'})
    ], axis=1).fillna('')
    
    print(df_display_pre.to_string())

    
    # --- TABLA 2: ANÁLISIS POST-PLEBISCITO ---
    print("\n\n--- 🗓️  Discurso DESPUÉS del Plebiscito (S1 vs S2) ---\n")
    
    terminos_post = terminos_filtrados[terminos_filtrados['Dataset'] == 'Plebiscito_POST']
    
    # Prepara las columnas para la tabla comparativa POST
    terminos_post_s1 = terminos_post[terminos_post['Cluster'] == CLUSTER_S1][['Termino', 'Score_TFIDF_Avg']].head(N_TOP_TERMINOS).reset_index(drop=True)
    terminos_post_s2 = terminos_post[terminos_post['Cluster'] == CLUSTER_S2][['Termino', 'Score_TFIDF_Avg']].head(N_TOP_TERMINOS).reset_index(drop=True)

    df_display_post = pd.concat([
        terminos_post_s1.rename(columns={'Termino': f'Top Términos ({CLUSTER_S1})', 'Score_TFIDF_Avg': 'Score'}),
        terminos_post_s2.rename(columns={'Termino': f'Top Términos ({CLUSTER_S2})', 'Score_TFIDF_Avg': 'Score'})
    ], axis=1).fillna('')

    print(df_display_post.to_string())


# 2. ANÁLISIS DE NODOS CENTRALES (ACTORES MÁS RELEVANTES)
# Este análisis ya tiene el formato correcto, comparando S1 vs S2 por período.
print(f"\n\n{'='*30} Análisis de Nodos Centrales {'='*30}\n")

# Filtra el DataFrame de nodos para el algoritmo seleccionado.
nodos_filtrados = df_nodos[df_nodos['Algoritmo'] == ALGORITMO_SELECCIONADO]

# --- NODOS PRE-PLEBISCITO ---
nodos_pre = nodos_filtrados[nodos_filtrados['Dataset'] == 'Plebiscito_PRE']
nodos_pre_s1 = nodos_pre[nodos_pre['Cluster'] == CLUSTER_S1][['Nodo', 'Grado']].head(N_TOP_NODOS).reset_index(drop=True)
nodos_pre_s2 = nodos_pre[nodos_pre['Cluster'] == CLUSTER_S2][['Nodo', 'Grado']].head(N_TOP_NODOS).reset_index(drop=True)
df_display_nodos_pre = pd.concat([
    nodos_pre_s1.rename(columns={'Nodo': f'Nodos PRE ({CLUSTER_S1})', 'Grado': 'Grado S1'}),
    nodos_pre_s2.rename(columns={'Nodo': f'Nodos PRE ({CLUSTER_S2})', 'Grado': 'Grado S2'})
], axis=1).fillna('')

print("--- 👥 Actores más relevantes ANTES del plebiscito ---")
print(df_display_nodos_pre.to_string())


# --- NODOS POST-PLEBISCITO ---
nodos_post = nodos_filtrados[nodos_filtrados['Dataset'] == 'Plebiscito_POST']
nodos_post_s1 = nodos_post[nodos_post['Cluster'] == CLUSTER_S1][['Nodo', 'Grado']].head(N_TOP_NODOS).reset_index(drop=True)
nodos_post_s2 = nodos_post[nodos_post['Cluster'] == CLUSTER_S2][['Nodo', 'Grado']].head(N_TOP_NODOS).reset_index(drop=True)
df_display_nodos_post = pd.concat([
    nodos_post_s1.rename(columns={'Nodo': f'Nodos POST ({CLUSTER_S1})', 'Grado': 'Grado S1'}),
    nodos_post_s2.rename(columns={'Nodo': f'Nodos POST ({CLUSTER_S2})', 'Grado': 'Grado S2'})
], axis=1).fillna('')

print("\n--- 👥 Actores más relevantes DESPUÉS del plebiscito ---")
print(df_display_nodos_post.to_string())

# 1. ANÁLISIS DE TÉRMINOS POR TIPO DE N-GRAM
# Itera sobre cada tipo de n-grama para analizarlo por separado.
for ngram_tipo in df_terminos['Tipo_Ngram'].unique():
    print(f"\n\n{'='*30} Análisis para N-Grams: {ngram_tipo} {'='*30}\n")
    
    # Filtra el DataFrame de términos para el algoritmo y n-gram actual.
    terminos_filtrados = df_terminos[
        (df_terminos['Algoritmo'] == ALGORITMO_SELECCIONADO) & 
        (df_terminos['Tipo_Ngram'] == ngram_tipo)
    ]
    
    # Separa los DataFrames de términos para el período PRE y POST.
    terminos_pre = terminos_filtrados[terminos_filtrados['Dataset'] == 'Plebiscito_PRE']
    terminos_post = terminos_filtrados[terminos_filtrados['Dataset'] == 'Plebiscito_POST']
    
    # Itera sobre cada clúster para analizar su discurso.
    for cluster_name in [CLUSTER_S1, CLUSTER_S2]:
        print(f"\n--- 🗣️ Evolución del Discurso del Clúster: {cluster_name} ---\n")
        
        # Usa sets para comparar eficientemente los términos PRE y POST.
        # Los sets contienen los términos más importantes para cada período.
        set_terminos_pre = set(terminos_pre[terminos_pre['Cluster'] == cluster_name]['Termino'])
        set_terminos_post = set(terminos_post[terminos_post['Cluster'] == cluster_name]['Termino'])
        
        # --- Cálculo de la evolución ---
        # Intersección: Términos que aparecen en ambos sets.
        terminos_mantenidos = list(set_terminos_pre.intersection(set_terminos_post))
        # Diferencia: Términos en PRE que no están en POST.
        terminos_perdidos = list(set_terminos_pre - set_terminos_post)
        # Diferencia: Términos en POST que no están en PRE.
        terminos_nuevos = list(set_terminos_post - set_terminos_pre)
        
        # --- Impresión de resultados ---
        print(f"✅ Términos Mantenidos (temas centrales persistentes):")
        print(f"   {terminos_mantenidos[:N_TERMINOS_A_MOSTRAR]}\n")
        
        print(f"❌ Términos Perdidos (temas que perdieron relevancia post-plebiscito):")
        print(f"   {terminos_perdidos[:N_TERMINOS_A_MOSTRAR]}\n")
        
        print(f"✨ Términos Nuevos (temas emergentes post-plebiscito):")
        print(f"   {terminos_nuevos[:N_TERMINOS_A_MOSTRAR]}\n")

# 2. ANÁLISIS DE NODOS CENTRALES (ACTORES MÁS RELEVANTES)
# Este análisis es independiente del tipo de n-gram, por lo que se hace una sola vez.
print(f"\n\n{'='*30} Análisis de Nodos Centrales {'='*30}\n")

# Filtra el DataFrame de nodos para el algoritmo seleccionado.
nodos_filtrados = df_nodos[df_nodos['Algoritmo'] == ALGORITMO_SELECCIONADO]

# --- NODOS PRE-PLEBISCITO ---
nodos_pre = nodos_filtrados[nodos_filtrados['Dataset'] == 'Plebiscito_PRE']
nodos_pre_s1 = nodos_pre[nodos_pre['Cluster'] == CLUSTER_S1][['Nodo', 'Grado']].head().reset_index(drop=True)
nodos_pre_s2 = nodos_pre[nodos_pre['Cluster'] == CLUSTER_S2][['Nodo', 'Grado']].head().reset_index(drop=True)
df_display_pre = pd.concat([
    nodos_pre_s1.rename(columns={'Nodo': f'Nodos PRE ({CLUSTER_S1})', 'Grado': 'Grado S1'}),
    nodos_pre_s2.rename(columns={'Nodo': f'Nodos PRE ({CLUSTER_S2})', 'Grado': 'Grado S2'})
], axis=1).fillna('')

print("--- 👥 Actores más relevantes ANTES del plebiscito ---")
print(df_display_pre.to_string())


# --- NODOS POST-PLEBISCITO ---
nodos_post = nodos_filtrados[nodos_filtrados['Dataset'] == 'Plebiscito_POST']
nodos_post_s1 = nodos_post[nodos_post['Cluster'] == CLUSTER_S1][['Nodo', 'Grado']].head().reset_index(drop=True)
nodos_post_s2 = nodos_post[nodos_post['Cluster'] == CLUSTER_S2][['Nodo', 'Grado']].head().reset_index(drop=True)
df_display_post = pd.concat([
    nodos_post_s1.rename(columns={'Nodo': f'Nodos POST ({CLUSTER_S1})', 'Grado': 'Grado S1'}),
    nodos_post_s2.rename(columns={'Nodo': f'Nodos POST ({CLUSTER_S2})', 'Grado': 'Grado S2'})
], axis=1).fillna('')

print("\n--- 👥 Actores más relevantes DESPUÉS del plebiscito ---")
print(df_display_post.to_string())
# Out:
# ==========================================================================================
# 🔎 ANÁLISIS DETALLADO DE LA EVOLUCIÓN DEL DISCURSO PARA: 'Local Search (b=0.01)'
# ==========================================================================================
#
#
# ============================== Análisis para N-Grams: Unigramas ==============================
#
# --- 🗓️  Discurso ANTES del Plebiscito (S1 vs S2) ---
#
#    Top Términos (S1)    Score Top Términos (S2)    Score
# 0            rechazo  0.09609             boric  0.06406
# 1                udi  0.07482           apruebo  0.05884
# 2       constitución  0.07195      constitución  0.05847
# 3            senador  0.06861        plebiscito  0.05714
# 4              carta  0.06344             nueva  0.05484
# 5         convención  0.06210           rechazo  0.05002
# 6              lagos  0.06195    constitucional  0.04423
# 7              texto  0.06146        septiembre  0.04253
# 8     constitucional  0.06124           gabriel  0.04232
# 9              nueva  0.05634          ministra  0.04077
# 10             vamos  0.05452         propuesta  0.03980
# 11           apruebo  0.05429           proceso  0.03637
# 12        plebiscito  0.05338        convención  0.03526
# 13     constituyente  0.05301           partido  0.03487
# 14           partido  0.05301           campaña  0.03447
#
#
# --- 🗓️  Discurso DESPUÉS del Plebiscito (S1 vs S2) ---
#
#    Top Términos (S1)    Score Top Términos (S2)    Score
# 0              vamos  0.07227             boric  0.06685
# 1       constitución  0.06665           proceso  0.05425
# 2            partido  0.06663             nueva  0.04926
# 3              nuevo  0.06632        plebiscito  0.04864
# 4            proceso  0.06631          gabinete  0.04812
# 5              nueva  0.06119      constitución  0.04585
# 6                udi  0.06112          ministra  0.04411
# 7                 rn  0.05930    constitucional  0.04359
# 8           diputada  0.05754           gabriel  0.04285
# 9          diputados  0.05754           rechazo  0.04168
# 10          comisión  0.05739            cambio  0.04001
# 11     constituyente  0.05704     constituyente  0.03936
# 12            cámara  0.05350             nuevo  0.03909
# 13          partidos  0.04729           partido  0.03684
# 14           acuerdo  0.04691           acuerdo  0.03617
#
#
# ============================== Análisis para N-Grams: Bigramas ==============================
#
# --- 🗓️  Discurso ANTES del Plebiscito (S1 vs S2) ---
#
#             Top Términos (S1)    Score          Top Términos (S2)    Score
# 0          nueva constitución  0.19677         nueva constitución  0.16991
# 1   convención constitucional  0.14781              gabriel boric  0.16402
# 2               ricardo lagos  0.13458          plebiscito salida  0.08307
# 3       proceso constituyente  0.12902      proceso constituyente  0.08147
# 4             apruebo rechazo  0.12025            giorgio jackson  0.07619
# 5              opción rechazo  0.10482          diario financiero  0.07503
# 6           plebiscito salida  0.10324      plebiscito septiembre  0.07181
# 7        texto constitucional  0.10294  convención constitucional  0.07028
# 8         partido republicano  0.09770            propuesta nueva  0.07027
# 9          rechazo plebiscito  0.07742             camila vallejo  0.06967
# 10            cara plebiscito  0.06635            apruebo rechazo  0.06586
# 11            propuesta nueva  0.06542          michelle bachelet  0.06105
# 12               gana rechazo  0.06091               izkia siches  0.05542
# 13         próximo septiembre  0.05990            cara plebiscito  0.05076
# 14              nuevo proceso  0.05761       texto constitucional  0.04593
#
#
# --- 🗓️  Discurso DESPUÉS del Plebiscito (S1 vs S2) ---
#
#             Top Términos (S1)    Score          Top Términos (S2)    Score
# 0       proceso constituyente  0.23111              gabriel boric  0.17211
# 1               nuevo proceso  0.17418      proceso constituyente  0.13445
# 2          nueva constitución  0.16636         nueva constitución  0.12989
# 3            cámara diputados  0.11538            cambio gabinete  0.09782
# 4             triunfo rechazo  0.11132          plebiscito salida  0.08272
# 5         partido republicano  0.08302              nuevo proceso  0.08093
# 6            nueva convención  0.07970          diario financiero  0.07959
# 7            apruebo dignidad  0.07330            triunfo rechazo  0.07610
# 8           partido comunista  0.07131             camila vallejo  0.06916
# 9          rechazo plebiscito  0.06121            comité político  0.06699
# 10  convención constitucional  0.05994          ministro hacienda  0.06520
# 11     proceso constitucional  0.05693               mario marcel  0.06302
# 12          plebiscito salida  0.05139     proceso constitucional  0.06157
# 13          fuerzas políticas  0.04782  convención constitucional  0.05929
# 14          diario financiero  0.04573              carolina tohá  0.05567
#
#
# ============================== Análisis para N-Grams: Uni_y_Bigramas ==============================
#
# --- 🗓️  Discurso ANTES del Plebiscito (S1 vs S2) ---
#
#    Top Términos (S1)    Score   Top Términos (S2)    Score
# 0            rechazo  0.09193               boric  0.06123
# 1                udi  0.07205             apruebo  0.05585
# 2       constitución  0.06905        constitución  0.05556
# 3            senador  0.06580          plebiscito  0.05427
# 4              carta  0.06056               nueva  0.05198
# 5         convención  0.05967             rechazo  0.04745
# 6              texto  0.05959  nueva constitución  0.04606
# 7              lagos  0.05933      constitucional  0.04194
# 8     constitucional  0.05849          septiembre  0.04024
# 9              nueva  0.05388             gabriel  0.04022
# 10             vamos  0.05247       gabriel boric  0.04006
# 11           apruebo  0.05233            ministra  0.03872
# 12           partido  0.05132           propuesta  0.03788
# 13        plebiscito  0.05080             proceso  0.03451
# 14     constituyente  0.05066          convención  0.03341
#
#
# --- 🗓️  Discurso DESPUÉS del Plebiscito (S1 vs S2) ---
#
#         Top Términos (S1)    Score Top Términos (S2)    Score
# 0                   vamos  0.06984             boric  0.06401
# 1                 partido  0.06460           proceso  0.05192
# 2            constitución  0.06459             nueva  0.04698
# 3                 proceso  0.06406        plebiscito  0.04635
# 4                   nuevo  0.06397          gabinete  0.04520
# 5                     udi  0.05909      constitución  0.04373
# 6                   nueva  0.05898          ministra  0.04202
# 7                      rn  0.05759    constitucional  0.04142
# 8                diputada  0.05660           gabriel  0.04090
# 9               diputados  0.05639     gabriel boric  0.04043
# 10               comisión  0.05637           rechazo  0.03942
# 11          constituyente  0.05491            cambio  0.03766
# 12  proceso constituyente  0.05266     constituyente  0.03762
# 13                 cámara  0.05253             nuevo  0.03728
# 14               partidos  0.04571           partido  0.03526
#
#
# ============================== Análisis de Nodos Centrales ==============================
#
# --- 👥 Actores más relevantes ANTES del plebiscito ---
#         Nodos PRE (S1)  Grado S1     Nodos PRE (S2)  Grado S2
# 0        javier macaya        18      gabriel boric       461
# 1        ricardo lagos        17    giorgio jackson        99
# 2         rojo edwards         9     camila vallejo        92
# 3         elisa loncon         7  michelle bachelet        67
# 4  juan antonio coloma         5       izkia siches        65
#
# --- 👥 Actores más relevantes DESPUÉS del plebiscito ---
#   Nodos POST (S1)  Grado S1  Nodos POST (S2)  Grado S2
# 0   karol cariola        32    gabriel boric       469
# 1   javier macaya        17     mario marcel        74
# 2    pamela jiles        16   camila vallejo        58
# 3     luz poblete        14  ana lya uriarte        56
# 4  diego schalper        10  giorgio jackson        51
#
#
# ============================== Análisis para N-Grams: Unigramas ==============================
#
#
# --- 🗣️ Evolución del Discurso del Clúster: S1 ---
#
# ✅ Términos Mantenidos (temas centrales persistentes):
#    ['udi', 'senador', 'proceso', 'convención', 'rechazo', 'plebiscito', 'constitucional', 'nueva', 'dc', 'texto', 'constitución', 'parte', 'grupo', 'constituyente', 'partido']
#
# ❌ Términos Perdidos (temas que perdieron relevancia post-plebiscito):
#    ['propuesta', 'apruebo', 'nacional', 'político', 'carta', 'bien', 'jorge', 'hoy', 'opción', 'caso', 'septiembre', 'lagos', 'dice', 'ricardo']
#
# ✨ Términos Nuevos (temas emergentes post-plebiscito):
#    ['acuerdo', 'nuevo', 'mesa', 'proyecto', 'rn', 'diputada', 'expertos', 'diputados', 'presidenta', 'diputado', 'triunfo', 'comisión', 'cámara', 'partidos']
#
#
# --- 🗣️ Evolución del Discurso del Clúster: S2 ---
#
# ✅ Términos Mantenidos (temas centrales persistentes):
#    ['nuevo', 'plebiscito', 'acuerdo', 'apruebo', 'constitucional', 'gabriel', 'constitución', 'ministra', 'constituyente', 'partido', 'ministro', 'proceso', 'hacer', 'parte', 'rechazo']
#
# ❌ Términos Perdidos (temas que perdieron relevancia post-plebiscito):
#    ['propuesta', 'campaña', 'convención', 'proyecto', 'va', 'jackson', 'caso', 'vallejo', 'texto', 'septiembre', 'salida']
#
# ✨ Términos Nuevos (temas emergentes post-plebiscito):
#    ['luego', 'interior', 'político', 'reunión', 'moneda', 'vamos', 'social', 'cambio', 'gabinete', 'marcel', 'congreso']
#
#
#
# ============================== Análisis para N-Grams: Bigramas ==============================
#
#
# --- 🗣️ Evolución del Discurso del Clúster: S1 ---
#
# ✅ Términos Mantenidos (temas centrales persistentes):
#    ['gabriel boric', 'giorgio jackson', 'diario financiero', 'rechazo plebiscito', 'michelle bachelet', 'propuesta nueva', 'convención constitucional', 'proceso constituyente', 'partido republicano', 'hoy día', 'socialismo democrático', 'plebiscito salida', 'partido comunista', 'nuevo proceso', 'camila vallejo']
#
# ❌ Términos Perdidos (temas que perdieron relevancia post-plebiscito):
#    ['cara plebiscito', 'caso gane', 'gana apruebo', 'plebiscito septiembre', 'ricardo lagos', 'propuesta constitucional', 'próximo septiembre', 'texto constitucional', 'opción rechazo', 'gane rechazo', 'carta magna', 'gana rechazo', 'apruebo rechazo']
#
# ✨ Términos Nuevos (temas emergentes post-plebiscito):
#    ['ana lya', 'apruebo dignidad', 'proceso constitucional', 'ministra interior', 'nueva convención', 'partidos políticos', 'lya uriarte', 'fuerzas políticas', 'carolina tohá', 'reforma tributaria', 'triunfo rechazo', 'resultado plebiscito', 'cámara diputados']
#
#
# --- 🗣️ Evolución del Discurso del Clúster: S2 ---
#
# ✅ Términos Mantenidos (temas centrales persistentes):
#    ['gabriel boric', 'giorgio jackson', 'apruebo dignidad', 'diario financiero', 'michelle bachelet', 'ministra interior', 'convención constitucional', 'proceso constituyente', 'socialismo democrático', 'hoy día', 'izkia siches', 'nueva constitución', 'partido comunista', 'nuevo proceso', 'camila vallejo']
#
# ❌ Términos Perdidos (temas que perdieron relevancia post-plebiscito):
#    ['cara plebiscito', 'apruebo plebiscito', 'plebiscito septiembre', 'propuesta nueva', 'partido republicano', 'propuesta constitucional', 'próximo septiembre', 'república gabriel', 'texto constitucional', 'gana rechazo', 'vocera camila', 'segpres giorgio', 'apruebo rechazo']
#
# ✨ Términos Nuevos (temas emergentes post-plebiscito):
#    ['ana lya', 'comité político', 'hacienda mario', 'mario marcel', 'proceso constitucional', 'cambio gabinete', 'lya uriarte', 'fuerzas políticas', 'carolina tohá', 'reforma tributaria', 'triunfo rechazo', 'resultado plebiscito', 'ministro hacienda']
#
#
#
# ============================== Análisis para N-Grams: Uni_y_Bigramas ==============================
#
#
# --- 🗣️ Evolución del Discurso del Clúster: S1 ---
#
# ✅ Términos Mantenidos (temas centrales persistentes):
#    ['udi', 'senador', 'proceso', 'convención', 'rechazo', 'constitucional', 'nueva', 'dc', 'texto', 'constitución', 'parte', 'grupo', 'constituyente', 'partido', 'nueva constitución']
#
# ❌ Términos Perdidos (temas que perdieron relevancia post-plebiscito):
#    ['apruebo', 'propuesta', 'nacional', 'político', 'carta', 'bien', 'convención constitucional', 'ricardo lagos', 'opción', 'septiembre', 'lagos', 'plebiscito', 'dice', 'ricardo']
#
# ✨ Términos Nuevos (temas emergentes post-plebiscito):
#    ['acuerdo', 'nuevo', 'mesa', 'proyecto', 'nuevo proceso', 'rn', 'diputada', 'proceso constituyente', 'expertos', 'diputados', 'presidenta', 'comisión', 'cámara', 'partidos']
#
#
# --- 🗣️ Evolución del Discurso del Clúster: S2 ---
#
# ✅ Términos Mantenidos (temas centrales persistentes):
#    ['nuevo', 'plebiscito', 'acuerdo', 'apruebo', 'constitucional', 'gabriel', 'constitución', 'ministra', 'partido', 'ministro', 'proceso', 'parte', 'rechazo', 'gabriel boric', 'respecto']
#
# ❌ Términos Perdidos (temas que perdieron relevancia post-plebiscito):
#    ['propuesta', 'campaña', 'convención', 'proyecto', 'va', 'jackson', 'caso', 'vallejo', 'texto', 'septiembre', 'hacer']
#
# ✨ Términos Nuevos (temas emergentes post-plebiscito):
#    ['interior', 'político', 'moneda', 'cambio gabinete', 'vamos', 'proceso constituyente', 'social', 'cambio', 'gabinete', 'constituyente', 'congreso']
#
#
#
# ============================== Análisis de Nodos Centrales ==============================
#
# --- 👥 Actores más relevantes ANTES del plebiscito ---
#         Nodos PRE (S1)  Grado S1     Nodos PRE (S2)  Grado S2
# 0        javier macaya        18      gabriel boric       461
# 1        ricardo lagos        17    giorgio jackson        99
# 2         rojo edwards         9     camila vallejo        92
# 3         elisa loncon         7  michelle bachelet        67
# 4  juan antonio coloma         5       izkia siches        65
#
# --- 👥 Actores más relevantes DESPUÉS del plebiscito ---
#   Nodos POST (S1)  Grado S1  Nodos POST (S2)  Grado S2
# 0   karol cariola        32    gabriel boric       469
# 1   javier macaya        17     mario marcel        74
# 2    pamela jiles        16   camila vallejo        58
# 3     luz poblete        14  ana lya uriarte        56
# 4  diego schalper        10  giorgio jackson        51

# %% [markdown]
# ## 🎯 Conclusiones del Análisis de Términos Distintivos (TF-IDF)
#
# * **Identificación de Polos:** El análisis de actores y términos confirma que el **Clúster S1** corresponde al polo del **"Rechazo / Oposición"** y el **Clúster S2** al **"Apruebo / Oficialismo"**.
#
# ### ⚡ Discurso PRE-Plebiscito: Polarización Clara
# * **S1 (Rechazo):** Su lenguaje es de oposición directa. Los términos más distintivos son **"rechazo"**, **"udi"**, **"senador"** y los nombres de figuras críticas al proceso como **"ricardo lagos"**.
# * **S2 (Apruebo):** Su lenguaje se centra en el gobierno y la propuesta. Los términos clave son **"boric"**, **"apruebo"** y **"nueva constitución"**.
# * **Resumen PRE:** Una clara división entre un polo que ataca y se define por la negativa, y otro que defiende el proyecto desde el oficialismo.
#
# ### 🏛️ Discurso POST-Plebiscito: Del Voto al Congreso
# El eje de la conversación se traslada de la campaña pública a la negociación institucional.
# * **S1 (Oposición):** Su discurso evoluciona. Deja de ser solo "Rechazo" y pasa a hablar del **"nuevo proceso"**, el **"acuerdo"** y el rol de la **"cámara de diputados"**. Actores como **Karol Cariola** se vuelven centrales, reflejando el inicio de las negociaciones en el Congreso.
# * **S2 (Oficialismo):** Su discurso se vuelve reactivo. Aunque **"boric"** sigue siendo central, emergen con fuerza términos como **"gabinete"**, **"cambio"** y **"mario marcel"**, reflejando la respuesta a la crisis y la nueva prioridad económica.
# * **Resumen POST:** La temática se vuelve más compleja y centrada en la "cocina" política.
#
# ---
# ### 🚀 Conclusión Principal:
# **El análisis TF-IDF muestra una transición clara: de una polarización pública y electoral ("Apruebo vs. Rechazo") a una negociación institucional y centrada en el Congreso, donde los discursos de ambos polos se reconfiguran en torno al "nuevo proceso constituyente".**

# %%
# Celda para Visualizar los Resultados del Topic Modeling

import pandas as pd
import os

# --- 1. CARGAR LOS RESULTADOS ---
# Asegúrate de que la ruta sea correcta.
results_dir = '../results'
path_temas = os.path.join(results_dir, 'analisis_topic_modeling.csv')

try:
    df_temas = pd.read_csv(path_temas, sep=';')
    print("✅ Archivo con resultados de Topic Modeling cargado exitosamente.")
except FileNotFoundError:
    print("❌ ERROR: No se encontró el archivo 'analisis_topic_modeling.csv'.")
    print("Asegúrate de haber ejecutado el script 'ejecutar_analisis_temas.py' primero desde tu terminal.")

# --- 2. FUNCIÓN PARA MOSTRAR LOS TEMAS DE FORMA ORDENADA ---
def mostrar_temas_por_escenario(df, dataset, cluster):
    """Filtra el DataFrame y muestra los temas para un escenario específico."""
    
    print("=" * 80)
    print(f"🗣️  TEMAS DE DISCUSIÓN PARA: {dataset} | {cluster}")
    print("=" * 80)
    
    # Filtra los datos para el escenario actual.
    df_filtrado = df[(df['Dataset'] == dataset) & (df['Cluster'] == cluster)]
    
    if df_filtrado.empty:
        print("No se encontraron temas para este escenario.")
        return
        
    # Muestra los temas encontrados, excluyendo el tema -1 (outliers).
    temas_principales = df_filtrado[df_filtrado['Topic'] != -1]
    
    # Selecciona y renombra columnas para una visualización limpia.
    display_cols = {
        'Topic': 'ID Tema',
        'Count': 'N° Noticias',
        'Name': 'Nombre del Tema',
        'Representation': 'Palabras Clave'
    }
    
    # Imprime la tabla formateada.
    print(temas_principales[display_cols.keys()].rename(columns=display_cols).to_string(index=False))

# --- 3. MOSTRAR LOS RESULTADOS PARA CADA ESCENARIO ---
if 'df_temas' in locals():
    mostrar_temas_por_escenario(df_temas, 'Plebiscito_PRE', 'S1')
    print("\n")
    mostrar_temas_por_escenario(df_temas, 'Plebiscito_PRE', 'S2')
    print("\n")
    mostrar_temas_por_escenario(df_temas, 'Plebiscito_POST', 'S1')
    print("\n")
    mostrar_temas_por_escenario(df_temas, 'Plebiscito_POST', 'S2')
# Out:
# ✅ Archivo con resultados de Topic Modeling cargado exitosamente.
# ================================================================================
# 🗣️  TEMAS DE DISCUSIÓN PARA: Plebiscito_PRE | S1
# ================================================================================
# No se encontraron temas para este escenario.
#
#
# ================================================================================
# 🗣️  TEMAS DE DISCUSIÓN PARA: Plebiscito_PRE | S2
# ================================================================================
#  ID Tema  N° Noticias                                 Nombre del Tema                                                                                                                         Palabras Clave
#        0          153         0_jackson_ministro_segpres_constitución              ['jackson', 'ministro', 'segpres', 'constitución', 'giorgio', 'nueva', 'boric', 'secretario', 'plebiscito', 'propuestas']
#        1          124              1_boric_constitución_nueva_proceso              ['boric', 'constitución', 'nueva', 'proceso', 'plebiscito', 'rechazo', 'vamos', 'mandatario', 'constituyente', 'gabriel']
#        2           88    2_contraloría_ministra_vallejo_investigación ['contraloría', 'ministra', 'vallejo', 'investigación', 'plebiscito', 'intervencionismo', 'moneda', 'siches', 'campaña', 'ministerio']
#        3           46            3_acuerdo_constitución_apruebo_nueva                    ['acuerdo', 'constitución', 'apruebo', 'nueva', 'partidos', 'mejorar', 'texto', 'boric', 'propuesta', 'plebiscito']
#        4           44        4_bachelet_derechos_comisionada_michelle                 ['bachelet', 'derechos', 'comisionada', 'michelle', 'presidenta', 'humanos', 'alta', 'onu', 'apruebo', 'expresidenta']
#        5           42               5_puntos_rechazo_encuesta_apruebo                    ['puntos', 'rechazo', 'encuesta', 'apruebo', 'cadem', 'aprobación', 'mientras', 'opción', 'boric', 'desaprobación']
#        6           41 6_convención_ceremonia_constitucional_quinteros                 ['convención', 'ceremonia', 'constitucional', 'quinteros', 'nacional', 'domínguez', 'cierre', '10', 'gaspar', 'maría']
#        7           38                7_reforma_proyecto_cámara_quórum                  ['reforma', 'proyecto', 'cámara', 'quórum', 'comisión', 'iniciativa', 'senado', 'constitución', 'congreso', 'semana']
#        8           37                 8_bachelet_boric_michelle_pablo                       ['bachelet', 'boric', 'michelle', 'pablo', 'milanés', 'apruebo', 'exmandataria', 'sirve', 'comisionada', 'alta']
#        9           34              9_rechazo_boric_apruebo_plebiscito             ['rechazo', 'boric', 'apruebo', 'plebiscito', 'proceso', 'nuevo', 'partidos', 'mandatario', 'constitucional', 'propuesta']
#       10           25     10_proceso_vallejo_constituyente_plebiscito         ['proceso', 'vallejo', 'constituyente', 'plebiscito', 'nuevo', 'ciudadanía', 'ministra', 'constitución', 'rechazo', 'mandato']
#       11           25                11_excepción_medida_ríos_decreto                        ['excepción', 'medida', 'ríos', 'decreto', 'emergencia', 'sur', 'araucanía', 'región', 'macrozona', 'congreso']
#
#
# ================================================================================
# 🗣️  TEMAS DE DISCUSIÓN PARA: Plebiscito_POST | S1
# ================================================================================
# No se encontraron temas para este escenario.
#
#
# ================================================================================
# 🗣️  TEMAS DE DISCUSIÓN PARA: Plebiscito_POST | S2
# ================================================================================
#  ID Tema  N° Noticias                           Nombre del Tema                                                                                                                   Palabras Clave
#        0          122          0_gabinete_boric_cambio_interior                         ['gabinete', 'boric', 'cambio', 'interior', 'político', 'jackson', 'moneda', 'siches', 'comité', 'tohá']
#        1           76          1_boric_mandatario_proceso_nueva           ['boric', 'mandatario', 'proceso', 'nueva', 'gabriel', 'constituyente', 'plebiscito', 'respecto', 'discurso', 'nuevo']
#        2           54        2_proceso_ministra_vallejo_uriarte       ['proceso', 'ministra', 'vallejo', 'uriarte', 'constituyente', 'acuerdo', 'nueva', 'partidos', 'congreso', 'constitución']
#        3           45      3_constitución_proceso_nueva_rechazo ['constitución', 'proceso', 'nueva', 'rechazo', 'constitucional', 'constituyente', 'boric', 'plebiscito', 'convención', 'texto']
#        4           39 4_marcel_inversionistas_economía_ministro                  ['marcel', 'inversionistas', 'economía', 'ministro', 'banco', 'año', 'hacienda', 'york', 'agenda', 'inversión']

# %%
# Celda Final para Visualizar Resultados Combinados (Temas y Nodos)

import pandas as pd
import os

# --- 1. CONFIGURACIÓN ---
# Define el algoritmo que quieres analizar. Debe ser el mismo que usaste en el script.
ALGORITMO_SELECCIONADO = 'Local Search (b=0.01)'
# Define cuántos nodos mostrar.
N_TOP_NODOS = 5

# --- 2. CARGAR TODOS LOS RESULTADOS NECESARIOS ---
results_dir = '../results'
path_temas = os.path.join(results_dir, 'analisis_topic_modeling.csv')
path_nodos = os.path.join(results_dir, 'exp_analisis_nodos.csv')

try:
    df_temas = pd.read_csv(path_temas, sep=';')
    df_nodos = pd.read_csv(path_nodos, sep=';')
    print("✅ Archivos de Temas y Nodos cargados exitosamente.")
except FileNotFoundError as e:
    print(f"❌ ERROR: No se encontró un archivo de resultados: {e}")
    print("Asegúrate de haber ejecutado los scripts 'ejecutar_analisis_clivajes...' y 'ejecutar_analisis_temas...' primero.")

# --- 3. FUNCIÓN MEJORADA PARA MOSTRAR TODA LA INFORMACIÓN ---
def mostrar_analisis_completo_por_escenario(df_temas, df_nodos, dataset, cluster):
    """
    Filtra y muestra los temas de discusión Y los actores principales
    para un escenario específico.
    """
    
    print("=" * 80)
    print(f"🔎 ANÁLISIS PARA: {dataset} | {cluster}")
    print("=" * 80)
    
    # --- Mostrar Temas de Discusión ---
    df_temas_filtrado = df_temas[(df_temas['Dataset'] == dataset) & (df_temas['Cluster'] == cluster)]
    
    if df_temas_filtrado.empty:
        print("No se encontraron temas de discusión para este escenario.")
    else:
        print("🗣️ TEMAS DE DISCUSIÓN PRINCIPALES:")
        temas_principales = df_temas_filtrado[df_temas_filtrado['Topic'] != -1]
        display_cols = {
            'Topic': 'ID', 'Count': 'N° Docs', 'Name': 'Nombre del Tema', 'Representation': 'Palabras Clave'
        }
        print(temas_principales[display_cols.keys()].rename(columns=display_cols).to_string(index=False))

    print("-" * 80) # Separador visual

    # --- Mostrar Nodos Principales ---
    # Filtra el df de nodos para el mismo escenario (algoritmo, dataset, cluster)
    df_nodos_filtrado = df_nodos[
        (df_nodos['Algoritmo'] == ALGORITMO_SELECCIONADO) &
        (df_nodos['Dataset'] == dataset) & 
        (df_nodos['Cluster'] == cluster)
    ]

    if df_nodos_filtrado.empty:
        print("No se encontraron nodos centrales para este escenario.")
    else:
        print(f"👥 ACTORES PRINCIPALES (Top {N_TOP_NODOS} con mayor grado):")
        nodos_principales = df_nodos_filtrado[['Nodo', 'Grado']].head(N_TOP_NODOS)
        print(nodos_principales.to_string(index=False))


# --- 4. MOSTRAR LOS RESULTADOS COMPLETOS PARA CADA ESCENARIO ---
if 'df_temas' in locals() and 'df_nodos' in locals():
    # Obtiene los clústeres y datasets del archivo de temas para iterar
    escenarios = df_temas[['Dataset', 'Cluster']].drop_duplicates().to_dict('records')
    
    for escenario in escenarios:
        mostrar_analisis_completo_por_escenario(df_temas, df_nodos, escenario['Dataset'], escenario['Cluster'])
        print("\n")
# Out:
# ✅ Archivos de Temas y Nodos cargados exitosamente.
# ================================================================================
# 🔎 ANÁLISIS PARA: Plebiscito_PRE | S2
# ================================================================================
# 🗣️ TEMAS DE DISCUSIÓN PRINCIPALES:
#  ID  N° Docs                                 Nombre del Tema                                                                                                                         Palabras Clave
#   0      153         0_jackson_ministro_segpres_constitución              ['jackson', 'ministro', 'segpres', 'constitución', 'giorgio', 'nueva', 'boric', 'secretario', 'plebiscito', 'propuestas']
#   1      124              1_boric_constitución_nueva_proceso              ['boric', 'constitución', 'nueva', 'proceso', 'plebiscito', 'rechazo', 'vamos', 'mandatario', 'constituyente', 'gabriel']
#   2       88    2_contraloría_ministra_vallejo_investigación ['contraloría', 'ministra', 'vallejo', 'investigación', 'plebiscito', 'intervencionismo', 'moneda', 'siches', 'campaña', 'ministerio']
#   3       46            3_acuerdo_constitución_apruebo_nueva                    ['acuerdo', 'constitución', 'apruebo', 'nueva', 'partidos', 'mejorar', 'texto', 'boric', 'propuesta', 'plebiscito']
#   4       44        4_bachelet_derechos_comisionada_michelle                 ['bachelet', 'derechos', 'comisionada', 'michelle', 'presidenta', 'humanos', 'alta', 'onu', 'apruebo', 'expresidenta']
#   5       42               5_puntos_rechazo_encuesta_apruebo                    ['puntos', 'rechazo', 'encuesta', 'apruebo', 'cadem', 'aprobación', 'mientras', 'opción', 'boric', 'desaprobación']
#   6       41 6_convención_ceremonia_constitucional_quinteros                 ['convención', 'ceremonia', 'constitucional', 'quinteros', 'nacional', 'domínguez', 'cierre', '10', 'gaspar', 'maría']
#   7       38                7_reforma_proyecto_cámara_quórum                  ['reforma', 'proyecto', 'cámara', 'quórum', 'comisión', 'iniciativa', 'senado', 'constitución', 'congreso', 'semana']
#   8       37                 8_bachelet_boric_michelle_pablo                       ['bachelet', 'boric', 'michelle', 'pablo', 'milanés', 'apruebo', 'exmandataria', 'sirve', 'comisionada', 'alta']
#   9       34              9_rechazo_boric_apruebo_plebiscito             ['rechazo', 'boric', 'apruebo', 'plebiscito', 'proceso', 'nuevo', 'partidos', 'mandatario', 'constitucional', 'propuesta']
#  10       25     10_proceso_vallejo_constituyente_plebiscito         ['proceso', 'vallejo', 'constituyente', 'plebiscito', 'nuevo', 'ciudadanía', 'ministra', 'constitución', 'rechazo', 'mandato']
#  11       25                11_excepción_medida_ríos_decreto                        ['excepción', 'medida', 'ríos', 'decreto', 'emergencia', 'sur', 'araucanía', 'región', 'macrozona', 'congreso']
# --------------------------------------------------------------------------------
# 👥 ACTORES PRINCIPALES (Top 5 con mayor grado):
#              Nodo  Grado
#     gabriel boric    461
#   giorgio jackson     99
#    camila vallejo     92
# michelle bachelet     67
#      izkia siches     65
#
#
# ================================================================================
# 🔎 ANÁLISIS PARA: Plebiscito_POST | S2
# ================================================================================
# 🗣️ TEMAS DE DISCUSIÓN PRINCIPALES:
#  ID  N° Docs                           Nombre del Tema                                                                                                                   Palabras Clave
#   0      122          0_gabinete_boric_cambio_interior                         ['gabinete', 'boric', 'cambio', 'interior', 'político', 'jackson', 'moneda', 'siches', 'comité', 'tohá']
#   1       76          1_boric_mandatario_proceso_nueva           ['boric', 'mandatario', 'proceso', 'nueva', 'gabriel', 'constituyente', 'plebiscito', 'respecto', 'discurso', 'nuevo']
#   2       54        2_proceso_ministra_vallejo_uriarte       ['proceso', 'ministra', 'vallejo', 'uriarte', 'constituyente', 'acuerdo', 'nueva', 'partidos', 'congreso', 'constitución']
#   3       45      3_constitución_proceso_nueva_rechazo ['constitución', 'proceso', 'nueva', 'rechazo', 'constitucional', 'constituyente', 'boric', 'plebiscito', 'convención', 'texto']
#   4       39 4_marcel_inversionistas_economía_ministro                  ['marcel', 'inversionistas', 'economía', 'ministro', 'banco', 'año', 'hacienda', 'york', 'agenda', 'inversión']
# --------------------------------------------------------------------------------
# 👥 ACTORES PRINCIPALES (Top 5 con mayor grado):
#            Nodo  Grado
#   gabriel boric    469
#    mario marcel     74
#  camila vallejo     58
# ana lya uriarte     56
# giorgio jackson     51

# %% [markdown]
# ## 🎯 Conclusiones del Análisis de Topic Modeling (Clúster Oficialismo/Apruebo)
#
# * **Identificación del Clúster:** Los actores principales (Boric, Jackson, Vallejo, Bachelet) confirman que el clúster analizado (`S2`) corresponde al polo del **Oficialismo / Apruebo**.
#
# ### 📝 Agenda PRE-Plebiscito: Campaña "Multi-Frente"
# El discurso antes de la elección era amplio y cubría múltiples frentes simultáneamente:
# * **Promoción:** Impulso del "proceso constituyente" y la "nueva constitución".
# * **Legitimación:** Búsqueda de respaldos clave, con temas específicos dedicados a las figuras de **Michelle Bachelet** y **Ricardo Lagos**.
# * **Defensa:** Gestión de controversias, como las acusaciones de "intervencionismo electoral" investigadas por la **Contraloría**.
# * **Contingencia:** Seguimiento de las encuestas ("Cadem") y gestión de problemas de gobierno como el "estado de excepción".
#
# ### 📉 Agenda POST-Plebiscito: Contracción y Gestión de Crisis
# Tras la derrota, la agenda se contrae y se enfoca en la crisis inmediata:
# * **Daño Político:** El tema dominante es el **"cambio de gabinete"**, con la salida de ministros como Izkia Siches y Giorgio Jackson.
# * **Estabilidad Económica:** Emerge un nuevo y fuerte discurso centrado en el Ministro de Hacienda, **Mario Marcel**, para calmar a los mercados e inversionistas.
# * **Rearticulación Política:** La conversación se traslada al Congreso, con la aparición de la nueva Ministra Segpres, **Ana Lya Uriarte**, como figura clave en la negociación del "nuevo proceso".
#
# ---
# ### 🚀 Conclusión Principal:
# **El discurso del oficialismo pasó de una narrativa de campaña expansiva y multifacética a una de gestión de crisis, enfocada en la reestructuración política interna y en proyectar estabilidad económica.**
